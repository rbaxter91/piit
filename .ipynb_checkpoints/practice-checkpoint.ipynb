# %%
a=1
b=2
c=a+b

# %%
c
# Out:
# 3

# %%
e=5
f=6
g=e*f

# %%
g
# Out:
# 30

# %%
string = `Dhiaj`
# Out:
#   Cell In[1], line 1
#     string = `Dhiaj`
#              ^
# SyntaxError: invalid syntax

# %%
string = Dhiraj
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 string = Dhiraj
#
# NameError: name 'Dhiraj' is not defined

# %%
string1 = 'Rebecca'
print (string1)
# Out:
# Rebecca

# %%
string1 = 'Rebecca'
string2 = 'Harper'
print (string1, string2)
# Out:
# Rebecca Harper

# %%
string1 = 'Rebecca'
string2 = 'Baxter'

# %%
string1 = 'Rebecca'
string2 = 'Baxter'
print (string1, string2)
# Out:
# Rebecca Baxter

# %%
string1 = 'My'
string2 = "name"
string3 = """Is Rebecca Baxter
            I Love
              Harper"""
print (string1)
print (string2)
print (string3)
# Out:
# My
# name
# Is Rebecca Baxter
#             I Love
#               Harper

# %%
ms = 'Geeksforgeeks'
print (ms)
# Out:
# Geeksforgeeks

# %%
print("/n2.concatenation")
# Out:
# /n2.concatenation

# %%
print("\n2. Concatenation")
full = string1 + " " + string2
print("concatenated:", full)
# Out:
# 2. Concatenation
# concatenated: My name

# %%
print("\nTitle")
full = string1 + " " + string2+ " " + string3
print("Title;", full)
# Out:
# Title
# Title; My name Is Rebecca Baxter
#             I Love
#               Harper

# %%
sc = 'Aelita' + '....' + "Khulan"
print(sc)
# Out:
# Aelita....Khulan

# %%
print("\t\t3. Repitition")
repeat = "Hi. How are you?" *5
print(repeat, end=': I reached end of string')
# Out:
# 		3. Repitition
# Hi. How are you?Hi. How are you?Hi. How are you?Hi. How are you?Hi. How are you?: I reached end of string

# %%
print("\t\tTitle")
repeat = "Are you home?" *3
print(repeat, end=': Yes, I am')
# Out:
# 		Title
# Are you home?Are you home?Are you home?: Yes, I am

# %%
print("\t\t Practice Repition")
repeat = "This is great" *4
print(repeat)
# Out:
# 		 Practice Repition
# This is greatThis is greatThis is greatThis is great

# %%
print("\t\t Practice Repiton")
repeat = "This is great" *4
print(repeat, end = 'Good job')
# Out:
# 		 Practice Repiton
# This is greatThis is greatThis is greatThis is greatGood job

# %%
print('\n')
print("4.Indexing")
text = "Guatemala"
print('The string is', text)
print("First character:", text[0])
print("last character:", text[2])
print("3rd character:", text[-1])
# Out:
# 4.Indexing
# The string is Guatemala
# First character: G
# last character: a
# 3rd character: a

# %%
print('\n')
print("4.indexing")
text = "Love"
print('the string is', text)
print("first character:", text[0])
print("last character:", text[
